# %% [markdown]
# # Thursday Exercises: String Operations & Type Conversion
#
# Welcome! Today you'll practice essential string methods and type conversion techniques using data from the Olist e-commerce dataset. Each exercise presents a realistic scenario. Write your code in the cell below each task. If you need a hint, expand the hint dropdown (optional). Good luck!

# %% [markdown]
# ## Exercise 1: Clean City Name
#
# **Task:** Fix the city name `"sao paulo"` so it appears as `"Sao Paulo"`.
#
# **Given:** `city = "sao paulo"`
# **Expected output:** `"Sao Paulo"`
#
# **Hint:** Use the `.title()` method.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Format Category
#
# **Task:** Transform the category `"cama_mesa_banho"` into a nicely formatted string `"Cama Mesa Banho"`.
#
# **Given:** `category = "cama_mesa_banho"`
# **Expected output:** `"Cama Mesa Banho"`
#
# **Hint:** First replace underscores with spaces, then apply title case.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Extract the Date
#
# **Task:** From the timestamp `"2017-10-02 10:56:33"`, extract only the date portion `"2017-10-02"`.
#
# **Given:** `timestamp = "2017-10-02 10:56:33"`
# **Expected output:** `"2017-10-02"`
#
# **Hint:** Use `.split()` and keep the first part.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Extract the Year
#
# **Task:** From the date string `"2017-10-02"`, extract the year as a string `"2017"`.
#
# **Given:** `date_str = "2017-10-02"`
# **Expected output:** `"2017"`
#
# **Hint:** Split by `"-"` and grab the first element.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: Price Calculation with Type Conversion
#
# **Task:** Convert the price string `"120.65"` to a float and add a freight value of `19.99`. Print the total.
#
# **Given:** `price_str = "120.65"`
# **Expected output:** `140.64`
#
# **Hint:** Use `float(price_str) + 19.99`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Check for Cancellation
#
# **Task:** Determine if the invoice `"C536379"` is a cancellation. Invoices starting with `"C"` are cancellations. Print `True` if it is.
#
# **Given:** `invoice = "C536379"`
# **Expected output:** `True`
#
# **Hint:** Use `.startswith("C")`.

# %%
# Your code here
