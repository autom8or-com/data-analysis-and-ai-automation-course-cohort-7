# %% [markdown]
# # Week 1 — Python Fundamentals — Thursday
# ## Phase 2a Python | PORA Academy Cohort 7

# %% [markdown]
# ## Instructions
#
# Olist data cleaning scenarios — all values are verified from the actual dataset. Apply the string and type conversion techniques from today's demo.

# %% [markdown]
# ### Exercise 1 — Title Case City
#
# city = "sao paulo"
#
# # Convert to title case
# # Expected: "Sao Paulo"
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 2 — Clean Category Name
#
# category = "cama_mesa_banho"
#
# # Replace underscores with spaces, then convert to title case
# # Expected: "Cama Mesa Banho"
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 3 — Extract Date from Timestamp
#
# timestamp = "2017-10-02 10:56:33"
#
# # Extract just the date part (before the space)
# # Expected: "2017-10-02"
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 4 — Extract Year as Integer
#
# date_str = "2017-10-02"
#
# # Extract the year as an integer
# # Expected: 2017  (int, not string)
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 5 — Safe Float Conversion
#
# price_str = "120.65"
# freight   = 19.99
#
# # Convert price_str to float, then add freight
# # Expected: 140.64
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 6 — Cancellation Check
#
# invoice = "C536379"
#
# # Check if this invoice is a cancellation (starts with "C")
# # Expected: True
#
# # Your code here:

# %%
# Your code here
