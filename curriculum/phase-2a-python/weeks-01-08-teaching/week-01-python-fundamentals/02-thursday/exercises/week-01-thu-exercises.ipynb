# %% [markdown]
# # Week 1 — Python Fundamentals — Thursday
# ## Phase 2a Python | PORA Academy Cohort 7

# %% [markdown]
# ## Instructions
#
# ## Week 1 — Python Fundamentals (Thursday)
#
# ### Learning Objectives
# - Apply string methods to clean and format data
# - Understand and perform type conversion
# - Use string checking methods (startswith, endswith, in, contains)
#
# ### Exercises
# Complete each task using Olist data cleaning scenarios.

# %% [markdown]
# ### Q1 — Title case city
#
# # 1. The city "sao paulo" needs to be "Sao Paulo"
# city = "sao paulo"
# # Your code here:
# # Expected: "Sao Paulo"

# %%
# Your code here

# %% [markdown]
# ### Q2 — Category formatting
#
# # 2. Category "cama_mesa_banho" needs to become "Cama Mesa Banho"
# category = "cama_mesa_banho"
# # Your code here:
# # Expected: "Cama Mesa Banho"

# %%
# Your code here

# %% [markdown]
# ### Q3 — Extract date
#
# # 3. Order timestamp — extract just the date part
# timestamp = "2017-10-02 10:56:33"
# # Your code here:
# # Expected: "2017-10-02"

# %%
# Your code here

# %% [markdown]
# ### Q4 — Extract year
#
# # 4. Extract the year from "2017-10-02"
# date_part = "2017-10-02"
# # Your code here:
# # Expected: "2017"

# %%
# Your code here

# %% [markdown]
# ### Q5 — Float conversion + math
#
# # 5. Given price_str, convert to float and add 19.99 freight
# price_str = "120.65"
# # Your code here:
# # Expected: 140.64

# %%
# Your code here

# %% [markdown]
# ### Q6 — Cancellation detection
#
# # 6. Check if "C536379" is a cancellation (starts with "C")
# invoice = "C536379"
# # Your code here:
# # Expected: True

# %%
# Your code here
