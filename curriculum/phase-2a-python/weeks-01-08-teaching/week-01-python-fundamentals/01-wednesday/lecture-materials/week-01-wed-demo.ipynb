# %% [markdown]
# # Week 1 — Python Fundamentals — Wednesday
# ## Phase 2a Python | PORA Academy Cohort 7

# %% [markdown]
# ## Instructor Notes
#
# **Topic:** Python Fundamentals — Wednesday
#
# **Learning Objectives:**
# - Set up and navigate Google Colab
# - Create variables and understand Python data types (str, int, float, bool, NoneType)
# - Perform arithmetic operations and understand type behaviour
# - Use print() and f-strings for output
#
# **Notes:**
# First session — allow full 20 min for Colab setup. All values are from real Olist data: anchor every concept in business context. No pandas yet. Group exercise at the end — each group of 10 uses a shared Colab notebook.

# %% [markdown]
# ## Part 1 — Colab Setup

# %%
# First cell every student runs
print("Hello, I am a data analyst!")
print("Welcome to PORA Academy Cohort 7")

# Keyboard shortcut cheatsheet:
# Shift + Enter  -> run cell and move to next
# Ctrl + M B     -> insert cell below
# Ctrl + M M     -> convert to Markdown cell
# Ctrl + M Y     -> convert to Code cell

# %% [markdown]
# ## Part 2 — Variables & Data Types

# %%
# A real order from the Olist dataset
order_id         = "e481f51cbdc54678b7cc49136f2d6af7"
order_status     = "delivered"
item_price       = 58.90
freight_value    = 13.29
is_delivered     = True
cancelled_orders = None

# Check types
print(type(order_id))            # <class 'str'>
print(type(item_price))          # <class 'float'>
print(type(is_delivered))        # <class 'bool'>
print(type(cancelled_orders))    # <class 'NoneType'>

# %% [markdown]
# ## Part 2 — Arithmetic Operations

# %%
item_price    = 58.90
freight_value = 13.29

# Calculate total order cost
total_cost = item_price + freight_value
print(total_cost)               # 72.19

# Profit margin calculation
revenue = 58.90
cost    = 40.00
margin  = (revenue - cost) / revenue * 100
print(f"Profit margin: {margin:.1f}%")   # Profit margin: 32.1%

# Integer vs float division
print(10 / 3)     # 3.3333333333333335
print(10 // 3)    # 3  (floor division)
print(10 % 3)     # 1  (remainder)

# %% [markdown]
# ## Part 3 — String Methods

# %%
city = "sao paulo"

print(city.upper())                        # SAO PAULO
print(city.title())                        # Sao Paulo
print(city.replace("sao", "rio"))          # rio paulo
print(len(city))                           # 9
print(city.strip())                        # removes leading/trailing spaces

# Indexing and slicing
order_id = "e481f51cbdc54678b7cc49136f2d6af7"
print(order_id[0])        # e
print(order_id[-1])       # 7
print(order_id[:8])       # e481f51c
print(order_id[8:16])     # bdc54678

# %% [markdown]
# ## Part 3 — f-strings

# %%
state  = "SP"
orders = 41746
print(f"State {state} has {orders:,} orders")
# State SP has 41,746 orders

# Multi-value f-string with formatting
item_price    = 58.90
freight_value = 13.29
total_cost    = item_price + freight_value
print(f"This order costs R${total_cost:.2f} including R${freight_value:.2f} freight")
# This order costs R$72.19 including R$13.29 freight

# %% [markdown]
# ## Summary
#
# Key takeaways from this session.
