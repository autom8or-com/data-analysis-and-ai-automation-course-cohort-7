# %% [markdown]
# # Week 1 — Python Fundamentals
# ## Phase 2a Python | PORA Academy Cohort 7

# %% [markdown]
# ## Instructor Notes
#
# **Topic:** Python Fundamentals
#
# **Learning Objectives:**
# - Set up and navigate Google Colab
# - Create variables and understand Python data types
# - Perform arithmetic operations and understand type behaviour
# - Use print() and f-strings for output
#
# **Notes:**

# %% [markdown]
# ## Part 1: Colab Setup

# %%
# Colab Setup — see teaching-curriculum.md for content

# %% [markdown]
# ## Part 2: Variables & Data Types

# %%
# Variables & Data Types — see teaching-curriculum.md for content

# %% [markdown]
# ## Part 3: Strings

# %%
# Strings — see teaching-curriculum.md for content

# %% [markdown]
# ## Part 4: Group Exercise

# %%
# Group Exercise — see teaching-curriculum.md for content

# %% [markdown]
# ## Summary
#
# Key takeaways from this session.
