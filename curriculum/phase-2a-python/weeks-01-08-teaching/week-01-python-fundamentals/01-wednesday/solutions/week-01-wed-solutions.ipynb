# %% [markdown]
# # Week 1 Wednesday: Variables, Data Types & Basic Operations
# ## INSTRUCTOR SOLUTIONS ONLY
#
# ## Group Exercise — Olist Data Analysis
#
# Given these verified values from the Olist dataset:
#
# ```python
# product_id = "4244733e06e7ecb4970a6e2683c13e61"
# seller_city = "campinas"
# price = 58.90
# freight = 13.29
# review_score = 4
# total_orders_brazil = 99441
# ```
#
# Tasks:
# 1. Calculate the total order value (price + freight) — Expected: 72.19
# 2. What percentage of Brazil's total orders are from SP state (41,746)? — Expected: 41.98%
# 3. Print seller_city in title case — Expected: Campinas
# 4. Extract the first 8 characters of product_id — Expected: '4244733e'
# 5. Create an f-string: "This order costs R$XX.XX including R$XX.XX freight" — Expected: "This order costs R$72.19 including R$13.29 freight"

# %%
# Olist dataset values
product_id = "4244733e06e7ecb4970a6e2683c13e61"
seller_city = "campinas"
price = 58.90
freight = 13.29
review_score = 4
total_orders_brazil = 99441
sp_orders = 41746  # number of orders from SP state

# %% [markdown]
# ### Task 1: Total Order Value
#
# Add `price` and `freight` to obtain the total cost. Use the `+` operator and print the result.

# %%
total = price + freight
print(total)

# %% [markdown]
# ### Task 2: Percentage of Brazil's Orders from SP State
#
# Calculate the percentage by dividing `sp_orders` by `total_orders_brazil`, multiply by 100, and format to two decimal places with an f‑string.

# %%
pct = (sp_orders / total_orders_brazil) * 100
print(f"{pct:.2f}%")

# %% [markdown]
# ### Task 3: Title Case
#
# The `.title()` method capitalises the first letter of every word. Apply it to `seller_city`.

# %%
print(seller_city.title())

# %% [markdown]
# ### Task 4: Extract First 8 Characters
#
# Use string slicing `[:8]` to retrieve the first eight characters of `product_id`.

# %%
print(product_id[:8])

# %% [markdown]
# ### Task 5: Formatted Order Summary
#
# Compute the total again (or reuse the variable) and embed the values in an f‑string with two decimal places and the `R$` currency symbol.

# %%
total = price + freight
print(f"This order costs R${total:.2f} including R${freight:.2f} freight")
