# %% [markdown]
# # Week 1 Wednesday: Variables, Data Types & Basic Operations
#
# Complete the exercises below. Each exercise lists the variables you must use and the expected output. Write your solution in the code cell provided.
#
# **Given variables for all exercises:**
# ```python
# product_id = "4244733e06e7ecb4970a6e2683c13e61"
# seller_city = "campinas"
# price = 58.90
# freight = 13.29
# review_score = 4
# total_orders_brazil = 99441
# sp_orders = 41746   # total orders from SP state
# ```

# %% [markdown]
# ### Exercise 1: Total Order Value
#
# **Task:** Calculate the total order value by adding `price` and `freight`. Assign the result to a variable named `total_order_value` and print it.
#
# **Hint:** Use the `+` operator.
#
# **Expected output:** `72.19`

# %%
# Your code here

# %% [markdown]
# ### Exercise 2: Percentage of Orders from SP
#
# **Task:** Calculate what percentage of Brazil’s total orders come from SP state. Use the variables `sp_orders` and `total_orders_brazil`. Print the result with two decimal places and a trailing percent sign.
#
# **Hint:** The formula is `(sp_orders / total_orders_brazil) * 100`. Format with `:.2f` inside an f-string.
#
# **Expected output:** `41.98%`

# %%
# Your code here

# %% [markdown]
# ### Exercise 3: Format Seller City
#
# **Task:** Print `seller_city` in **Title Case** (first letter of each word capitalised).
#
# **Hint:** Use the `.title()` string method.
#
# **Expected output:** `Campinas`

# %%
# Your code here

# %% [markdown]
# ### Exercise 4: Extract First 8 Characters of product_id
#
# **Task:** Extract the first 8 characters from `product_id` and store them in a variable named `short_id`. Print `short_id`.
#
# **Hint:** Use slicing: `product_id[:8]`.
#
# **Expected output:** `4244733e`

# %%
# Your code here

# %% [markdown]
# ### Exercise 5: Order Cost f-string
#
# **Task:** Create an f-string that displays the total order cost including freight, formatted exactly as:
# `This order costs R$XX.XX including R$XX.XX freight`
# where `XX.XX` are the real values of `price` and `freight` with two decimal places. Print the string.
#
# **Hint:** Add `price + freight` inside the f-string or use a pre‑calculated variable. Format numbers with `:.2f`.
#
# **Expected output:** `This order costs R$72.19 including R$13.29 freight`

# %%
# Your code here
