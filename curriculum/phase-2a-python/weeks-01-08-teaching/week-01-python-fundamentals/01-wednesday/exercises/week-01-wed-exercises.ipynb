# %% [markdown]
# # Wednesday Exercises: Variables, Data Types & Basic Operations

# %% [markdown]
# ## Setup: Run the cell below to define the Olist variables
#
# Execute this code before starting the exercises.

# %%
# Olist variables - run this cell first
product_id = "4244733e06e7ecb4970a6e2683c13e61"
seller_city = "campinas"
price = 58.90
freight = 13.29
review_score = 4
total_orders_brazil = 99441
sp_orders = 41746
order_id = "e481f51cbdc54678b7cc49136f2d6af7"

# %% [markdown]
# ## Exercises
#
# Complete each task in the code cell below.

# %% [markdown]
# 1. **Easy:** Print the data types of `product_id`, `price`, and `freight`.

# %%
# Your code here

# %% [markdown]
# 2. **Easy:** Calculate the total order value by adding `price` and `freight`. Store the result in a variable `total_cost` and print it.

# %%
# Your code here

# %% [markdown]
# 3. **Easy:** A product sold for `price = 58.90` and cost `40.00`. Calculate the profit margin as a percentage: `(revenue - cost) / revenue * 100`. Round to one decimal place and print: `Profit margin: XX.X%` (use f‑string).

# %%
# Your code here

# %% [markdown]
# 4. **Easy:** Perform floor division and modulus on `10` and `3`. Print the results with explanations, e.g., `10 // 3 = 3` and `10 % 3 = 1`.

# %%
# Your code here

# %% [markdown]
# 5. **Easy:** Using the `seller_city` string, print it in uppercase, title case, and its length, each on a new line.

# %%
# Your code here

# %% [markdown]
# 6. **Medium:** Extract different slices from `order_id` (`"e481f51cbdc54678b7cc49136f2d6af7"`). Print the first 8 characters, the last 4 characters, and the slice from index 8 to 16 (inclusive start, exclusive end). Label each output.

# %%
# Your code here

# %% [markdown]
# 7. **Medium:** Create an f‑string that uses `sp_orders` (41,746) and `total_orders_brazil` (99,441) to display: `"SP accounts for 41.98% of Brazil's orders"`. Format the percentage to two decimal places. Hint: calculate `percentage = sp_orders / total_orders_brazil * 100`.

# %%
# Your code here

# %% [markdown]
# 8. **Medium:** Using `price` and `freight`, build an f‑string that says: `"The total order value is R$72.19"`. Ensure freight is included in the total and the value shows two decimal places.

# %%
# Your code here

# %% [markdown]
# 9. **Challenge:** Write a function `format_order(order_id, price, freight)` that returns a string. The string should show the first 8 characters of `order_id` followed by `"..."`, then the total cost (`price + freight`) formatted to two decimals, and the freight value. Example: `"Order 4244733e... costs R$72.19 including R$13.29 freight"`. Test your function with the given `product_id`, `price`, and `freight` and print the result.

# %%
# Your code here
