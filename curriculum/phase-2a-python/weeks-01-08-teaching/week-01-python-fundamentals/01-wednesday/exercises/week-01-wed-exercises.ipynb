# %% [markdown]
# # Week 1 — Python Fundamentals
# ## Phase 2a Python | PORA Academy Cohort 7

# %% [markdown]
# ## Instructions
#
# ## Week 1 — Python Fundamentals
#
# ### Learning Objectives
# - Set up and navigate Google Colab
# - Create variables and understand Python data types
# - Perform arithmetic operations and understand type behaviour
# - Use print() and f-strings for output
#
# ### Exercises
# Complete each task in the code cells below. Expected outputs are shown in comments.

# %% [markdown]
# ### Q1 — Calculate total order value
#
# # 1. Calculate the total order value (price + freight)
# # Given values from Olist:
# price = 58.90
# freight = 13.29
# # Your code here:
# # Expected: 72.19

# %%
# Your code here

# %% [markdown]
# ### Q2 — SP state percentage
#
# # 2. What percentage of Brazil's total orders are from SP state?
# sp_orders = 41746
# total_orders = 99441
# # Your code here:
# # Expected: 41.98%

# %%
# Your code here

# %% [markdown]
# ### Q3 — Title case
#
# # 3. Print seller_city in title case
# seller_city = "campinas"
# # Your code here:
# # Expected: Campinas

# %%
# Your code here

# %% [markdown]
# ### Q4 — Slice product_id
#
# # 4. Extract the first 8 characters of product_id
# product_id = "4244733e06e7ecb4970a6e2683c13e61"
# # Your code here:
# # Expected: '4244733e'

# %%
# Your code here

# %% [markdown]
# ### Q5 — f-string with costs
#
# # 5. Create an f-string showing total order cost
# price = 58.90
# freight = 13.29
# # Your code here:
# # Expected: "This order costs R$72.19 including R$13.29 freight"

# %%
# Your code here
