# %% [markdown]
# # Week 1 — Python Fundamentals — Wednesday
# ## Phase 2a Python | PORA Academy Cohort 7

# %% [markdown]
# ## Instructions
#
# Work in your group of 10 on this shared Colab notebook. All values below come from the real Olist dataset — verify every result. Run each cell with Shift + Enter after writing your answer.

# %% [markdown]
# ### Exercise 1 — Total Order Value
#
# # Given:
# price    = 58.90
# freight  = 13.29
#
# # Calculate the total order value (price + freight)
# # Expected output: 72.19
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 2 — SP State Percentage
#
# # Given:
# sp_orders    = 41746
# total_orders = 99441
#
# # What percentage of Brazil's total orders are from SP state?
# # Expected output: 41.98%  (use f-string with :.2f%)
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 3 — Title Case City
#
# seller_city = "campinas"
#
# # Print seller_city in title case
# # Expected: Campinas
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 4 — String Slicing
#
# product_id = "4244733e06e7ecb4970a6e2683c13e61"
#
# # Extract the first 8 characters of product_id
# # Expected: '4244733e'
#
# # Your code here:

# %%
# Your code here

# %% [markdown]
# ### Exercise 5 — f-string
#
# price   = 58.90
# freight = 13.29
#
# # Create an f-string that outputs:
# # "This order costs R$72.19 including R$13.29 freight"
#
# # Your code here:

# %%
# Your code here
