# %% [markdown]
# **Exercise 1 – Easy**Create a dictionary called `payment_summary` that maps each payment type to its count. Use the provided lists:```pythonpayment_types = ['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined']payment_counts = [76795, 19784, 5775, 1529, 3]```Print the resulting dictionary.

# %%
# Hint: Use zip()
 to pair types and counts, then convert to dictpayment_types = ['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined']payment_counts = [76795, 19784, 5775, 1529, 3]# Your code here

# %% [markdown]
# **Exercise 2 – Easy**Using the `payment_summary` dictionary from the previous exercise:- Print the count for `'debit_card'`.- Use the `.get()` method to safely retrieve the count for `'bank_transfer'`, with a default value of `0`. Print the result.

# %%
# Access debit_card directly, then use get()
 for bank_transfer# (Assume payment_summary exists from previous cell)# Your code here

# %% [markdown]
# **Exercise 3 – Easy**Loop through `payment_summary` using a `for` loop and print each payment type and its count in the following format:```credit_card: 76795 ordersboleto: 19784 orders...```

# %%
# Iterate over dict items and format output# (Assume payment_summary exists)# Your code here

# %% [markdown]
# **Exercise 4 – Easy**Create a dictionary named `order` with the following key-value pairs:- `'order_id'`: `'ord_550'`- `'status'`: `'shipped'`- `'price'`: `210.5`- `'freight'`: `25.0`- `'state'`: `'RJ'`- `'review_score'`: `3`Then add a new key `'total'` that stores the sum of `price` and `freight`. Print the updated dictionary.

# %%
# Define order dict, then add 'total' keyorder = {    # Your key-value pairs here}# Your code here

# %% [markdown]
# **Exercise 5 – Easy**Define a function `classify_score(score)` that classifies a review score:- Returns `'High'` if score ≥ 4- Returns `'Medium'` if score == 3- Returns `'Low'` if score ≤ 2Test the function with scores 5, 3, and 1. Print each result.

# %%
def classify_score(score):    # Your conditional logic    pass# Test with 5, 3, 1print(...)

# %% [markdown]
# **Exercise 6 – Easy**A list of customer review scores is given:```pythonscores = [5, 4, 1, 5, 3, 2, 5, 4, 5, 1]```Using a `for` loop and your `classify_score` function, print each score and its classification, like:```Score 5: HighScore 4: High...```

# %%
scores = [5, 4, 1, 5, 3, 2, 5, 4, 5, 1]# Your loop here

# %% [markdown]
# **Exercise 7 – Easy**Create a list `state_dicts` containing one dictionary per state for the top 3 states (`'SP'`, `'RJ'`, `'MG'`). Each dictionary should have the keys `'state'` (the state code) and `'orders'` (set to `0` for now). Print the final list.

# %%
# Initiate empty list, then for each state append a dictstates = ['SP', 'RJ', 'MG']# Your code here

# %% [markdown]
# **Exercise 1 – Medium**Combine the following lists into a dictionary called `status_counts`:```pythonstatuses = ['delivered', 'shipped', 'canceled', 'unavailable', 'invoiced', 'processing', 'created', 'approved']counts = [96478, 1107, 625, 609, 314, 301, 5, 2]```Then, using a loop, print only the statuses where the count is greater than 500 in this format:```delivered (96478 orders)shipped (1107 orders)...```

# %%
# Combine using zip or loop to build dict, then filterstatuses = ['delivered', 'shipped', 'canceled', 'unavailable', 'invoiced', 'processing', 'created', 'approved']counts = [96478, 1107, 625, 609, 314, 301, 5, 2]# Your code here

# %% [markdown]
# **Exercise 2 – Medium**You have a dictionary of state order counts:```pythonstate_orders = {'SP': 41746, 'RJ': 12852, 'MG': 11635, 'RS': 5466, 'PR': 5045}```Write a function `filter_big_states(state_dict, threshold)` that returns a new dictionary containing only the states whose order count is strictly greater than `threshold`. Test it with `threshold=10000` and print the result.

# %%
state_orders = {'SP': 41746, 'RJ': 12852, 'MG': 11635, 'RS': 5466, 'PR': 5045}def filter_big_states(state_dict, threshold):    # Create new dict with states above threshold    pass# Test and printresult = filter_big_states(state_orders, 10000)
print(result)

# %% [markdown]
# **Exercise 3 – Medium**1. Define a function `classify_status(status)` that returns:   - `'Active'` for `'delivered'`, `'shipped'`, `'invoiced'`   - `'Problem'` for `'canceled'`, `'unavailable'`   - `'Other'` for any other status.2. Using the `status_counts` dictionary from the previous medium exercise (re‑create it here if needed), build a nested dictionary `status_report` where each key is a status and the value is another dictionary containing:   - `'count'`: the original count   - `'category'`: the result of `classify_status(status)`Print the entry for `'delivered'`.

# %%
# Define classify_status, then reconstruct status_counts if needed# Build status_report with nested dict# Your code here

# %% [markdown]
# **Challenge Exercise 1 – Payment Analysis**Using the payment data from an earlier easy exercise (or re‑list them here), perform a complete payment summary analysis:```pythonpayment_types = ['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined']payment_counts = [76795, 19784, 5775, 1529, 3]```1. Compute the total number of payments (sum of counts).2. Create a list called `payments_info` where each element is a dictionary with keys `'type'`, `'count'`, and `'percentage'` (percentage of total, rounded to one decimal).3. Write a function `top_payment_methods(payments, min_percent)` that returns a list of payment types that have a percentage strictly greater than `min_percent`.4. Test the function with `min_percent=5` and print the result.

# %%
# Your analysis herepayment_types = ['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined']payment_counts = [76795, 19784, 5775, 1529, 3]# Step 1,2,3,4

# %% [markdown]
# **Challenge Exercise 2 – Order Book**Create a complete order book for a fictional day:- Define a list `orders` containing 5 dictionaries. Each order should have keys: `'order_id'`, `'city'`, `'state'`, `'price'`, `'freight'`, `'review_score'`. Use realistic prices between R$20 and R$500 and states from SP, RJ, MG, RS, PR. Make up order IDs like `'A001'`, etc.- Write a function `order_summary(orders)` that returns a dictionary with the following keys:  - `'total_orders'`: total number of orders.  - `'average_total'`: average of `price + freight` across all orders (rounded to 2 decimals).  - `'states'`: a set of all unique states in the orders.  - `'score_distribution'`: a dictionary counting how many scores fall into `'High'` (≥4), `'Medium'` (==3), `'Low'` (≤2). (You may reuse your `classify_score` function from earlier or redefine it.)Test your function with your `orders` list and print the resulting summary.

# %%
# Define orders list and order_summary functionorders = [    # your 5 order dicts here]# Your code here
