# %% [markdown]
# # Week 2 — Collections & Control Flow: Thursday Exercises
# ## Phase 2a Python | PORA Academy Cohort 7
#
# Work through each question in order. All input data is pre-defined — **do not change the given variables**. Write your solution where you see `# Your code here`.
#
# **Topics covered**: dictionaries, nested dicts, if/elif/else, loops with conditionals, dict comprehensions.
#
# **This notebook also includes the Weekly Assignment (Question 9).**

# %%
# Real Olist values — use these throughout the exercises
order = {
    "order_id":     "e481f51cbdc54678b7cc49136f2d6af7",
    "status":       "delivered",
    "price":        58.90,
    "freight":      13.29,
    "state":        "SP",
    "review_score": 4
}

state_summary = {
    "SP": {"orders": 41746, "revenue": 5202955.05},
    "RJ": {"orders": 12852, "revenue": 1824092.67},
    "MG": {"orders": 11635, "revenue": 1585308.03}
}

statuses = ["delivered", "shipped", "canceled", "unavailable",
            "invoiced", "processing", "created", "approved"]
counts   = [96478, 1107, 625, 609, 314, 301, 5, 2]

print("Data ready!")

# %% [markdown]
# ## Question 1 — Accessing Dictionary Values
#
# Using the `order` dict:
#
# 1. Print the order's status. Expected: `delivered`
# 2. Print the order's price. Expected: `58.9`
# 3. Safely get the value for key `"seller"` — it doesn't exist. Expected: `unknown`
# 4. Calculate and print the total cost (price + freight). Expected: `72.19`
# 5. Print all the keys in the order dict as a list.

# %%
# Q1.1 — order status
# Your code here

# Q1.2 — order price
# Your code here

# Q1.3 — safe get for missing key "seller"
# Your code here

# Q1.4 — total cost (price + freight)
# Your code here

# Q1.5 — all keys as a list
# Your code here

# %% [markdown]
# ## Question 2 — Modifying and Iterating a Dictionary
#
# Using the `order` dict:
#
# 1. Add a new key `"total"` with the value `price + freight`
# 2. Update `"review_score"` to `5`
# 3. Print all key-value pairs using a `for` loop over `.items()`. Expected format: `status: delivered`

# %%
# Q2.1 — add "total" key
# Your code here

# Q2.2 — update review_score to 5
# Your code here

# Q2.3 — print all key-value pairs
# Your code here

# %% [markdown]
# ## Question 3 — Nested Dictionaries
#
# Using `state_summary`:
#
# 1. Print the number of orders for SP. Expected: `41746`
# 2. Print the revenue for RJ. Expected: `1824092.67`
# 3. Loop through all states and print: `"SP: 41,746 orders"` (one line per state)
# 4. Which state has the highest revenue? Expected: `SP`

# %%
# Q3.1 — SP orders
# Your code here

# Q3.2 — RJ revenue
# Your code here

# Q3.3 — loop: one line per state
# Your code here

# Q3.4 — state with highest revenue
# Hint: loop through state_summary and compare revenue values
# Your code here

# %% [markdown]
# ## Question 4 — Writing a Classifier Function
#
# Write a function `classify_delivery(days)` that returns:
# - `"Unknown"` if `days` is `None`
# - `"Fast"` if `days <= 7`
# - `"Normal"` if `days <= 14`
# - `"Slow"` if `days <= 30`
# - `"Very Slow"` otherwise
#
# Test it with: `[0, 5, 10, 20, 50, None]`
#
# Expected: `Fast, Fast, Normal, Slow, Very Slow, Unknown`

# %%
# Q4 — classify_delivery function
# Your code here

# Test with these values (do not change):
test_days = [0, 5, 10, 20, 50, None]
for days in test_days:
    print(f"{days} days → {classify_delivery(days)}")

# %% [markdown]
# ## Question 5 — Order Value Classifier
#
# Write a function `classify_order_value(price)` that returns:
# - `"Premium"` if price >= 500
# - `"Standard"` if price >= 100
# - `"Economy"` otherwise
#
# Test with: `[58.90, 120.65, 500.00, 6735.00]`
#
# Expected: `Economy, Standard, Premium, Premium`
#
# *Tip: the order of your conditions matters — put the most restrictive first.*

# %%
# Q5 — classify_order_value function
# Your code here

# Test with these values (do not change):
test_prices = [58.90, 120.65, 500.00, 6735.00]
for p in test_prices:
    print(f"R${p:.2f} → {classify_order_value(p)}")

# %% [markdown]
# ## Question 6 — Combining Loops and Conditionals
#
# Using the list of sample prices below and your `classify_order_value` function from Q5:
#
# 1. Count how many prices fall into each category (Economy, Standard, Premium)
# 2. Expected: `Economy: 4, Standard: 4, Premium: 2`
# 3. Build a results dict `{"Economy": N, "Standard": N, "Premium": N}` and print it

# %%
# Pre-defined data — do not change
sample_prices = [58.90, 120.65, 45.00, 780.00, 99.99,
                 350.00, 25.00, 6735.00, 115.00, 499.99]

# Q6.1 & Q6.2 — count each category using a loop + conditionals
# Your code here

# Q6.3 — build and print results dict
# Your code here

# %% [markdown]
# ## Question 7 — Dict Comprehensions
#
# 1. Using `statuses` and `counts`, build a dict `{status: count}` with a **dict comprehension**. Print `status_dict["delivered"]`. Expected: `96478`
# 2. Using a dict comprehension with a filter, keep only statuses where count > 500. Print the keys. Expected: `['delivered', 'shipped', 'canceled', 'unavailable']`
# 3. Build a percentage dict `{status: pct}` where `pct = round(count / total * 100, 1)`. Print `pct_dict["delivered"]`. Expected: `97.0`

# %%
# Q7.1 — dict comprehension: status → count
# Your code here

# Q7.2 — filtered dict: only counts > 500
# Your code here

# Q7.3 — percentage dict
total = sum(counts)
# Your code here

# %% [markdown]
# ## Question 8 — Group Exercise: Build a Status Summary Dict
#
# Olist records 99,441 orders across 8 status categories. Build a structured summary from the two parallel lists.
#
# 1. Create a dict mapping `status → count`. Expected: `{"delivered": 96478, ...}`
# 2. Loop and print only statuses where count > 500. Expected: `delivered (96478)`, `shipped (1107)`, `canceled (625)`, `unavailable (609)`
# 3. Write `classify_status(status)` returning `"Active"` for delivered/shipped/invoiced/processing, `"Problem"` for canceled/unavailable, `"Other"` otherwise. Test with all 8 statuses.
# 4. Build a nested dict `{status: {"count": N, "pct": X.X}}` using a dict comprehension.

# %%
# Verified Olist data — do not change
statuses = ["delivered", "shipped", "canceled", "unavailable",
            "invoiced", "processing", "created", "approved"]
counts   = [96478, 1107, 625, 609, 314, 301, 5, 2]

# Q8.1 — status → count dict
# Your code here

# Q8.2 — loop: statuses with count > 500
# Your code here

# Q8.3 — classify_status() function + test all 8
# Your code here

# Q8.4 — nested dict comprehension
total = sum(counts)
# Your code here

# %% [markdown]
# ## Weekly Assignment 2
#
# Submit `week2_assignment.ipynb` — due before next Wednesday.
#
# **Task 1.** Create a dictionary representing 3 Olist orders (invent order_ids, use realistic prices R$20–R$500). Each dict must include: `order_id`, `city`, `state`, `price`, `freight`, `review_score`.
#
# **Task 2.** Write a function `order_report(order_dict)` that:
# - Calculates total cost (price + freight)
# - Returns the string: `"Order from [city]: R$[total] — [Fast/Normal/Slow classification based on review score proxy]"`
#
# **Task 3.** Using `review_scores = [5, 4, 1, 5, 3, 2, 5, 4, 5, 1]`:
# - Count positives (≥4), neutrals (=3), negatives (≤2) using a loop
# - Repeat using a list comprehension + `.count()`
# - Verify both give the same answer. *(Expected: positive=6, neutral=1, negative=3)*
#
# **Task 4.** Write a function `top_states(state_dict, n)` that takes a `{state: order_count}` dict and returns the top `n` states sorted by count descending. Test with:
# ```python
# data = {"SP": 41746, "RJ": 12852, "MG": 11635, "RS": 5466, "PR": 5045}
# ```
# `top_states(data, 3)` should return `[("SP", 41746), ("RJ", 12852), ("MG", 11635)]`
