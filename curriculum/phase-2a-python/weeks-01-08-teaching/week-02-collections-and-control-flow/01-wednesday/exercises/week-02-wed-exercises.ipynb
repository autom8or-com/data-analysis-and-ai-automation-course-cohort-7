# %% [markdown]
# # Week 2 — Collections & Control Flow: Wednesday Exercises
# ## Phase 2a Python | PORA Academy Cohort 7
#
# Work through each question in order. All input data is pre-defined — **do not change the given variables**. Write your solution code where you see `# Your code here`.
#
# **Expected output format**: where a question states "Expected:", your code should produce exactly that result.
#
# **Topics covered**: lists, for loops, range(), enumerate(), zip(), list comprehensions, tuples.

# %%
# Real Olist values — use these throughout the exercises
# Do not change these variables

statuses = ["delivered", "shipped", "canceled", "unavailable",
            "invoiced", "processing", "created", "approved"]
counts   = [96478, 1107, 625, 609, 314, 301, 5, 2]

payment_types  = ["credit_card", "boleto", "voucher", "debit_card", "not_defined"]
payment_counts = [76795, 19784, 5775, 1529, 3]

review_scores = [5, 4, 1, 5, 3, 2, 5, 4, 5, 1]

print("Data ready!")

# %% [markdown]
# ## Question 1 — List Indexing and Slicing
#
# Using the `statuses` list, answer the following **without modifying the original list**.
#
# 1. How many order statuses are there? Expected: `8`
# 2. Print the first status. Expected: `delivered`
# 3. Print the last status using negative indexing. Expected: `approved`
# 4. Print the first three statuses as a slice. Expected: `['delivered', 'shipped', 'canceled']`
# 5. Is `'canceled'` in the list? Expected: `True`
# 6. Is `'refunded'` in the list? Expected: `False`

# %%
# Q1.1 — number of statuses
# Your code here

# Q1.2 — first status
# Your code here

# Q1.3 — last status (use negative indexing)
# Your code here

# Q1.4 — first three statuses
# Your code here

# Q1.5 — is 'canceled' in the list?
# Your code here

# Q1.6 — is 'refunded' in the list?
# Your code here

# %% [markdown]
# ## Question 2 — Modifying Lists
#
# Start with `top_states = ["SP", "RJ", "MG"]` and use list methods to perform each step **in order**.
#
# 1. Add `"RS"` to the end of the list
# 2. Insert `"BA"` at position 0 (the beginning)
# 3. Print the list — Expected: `['BA', 'SP', 'RJ', 'MG', 'RS']`
# 4. Remove `"BA"` from the list
# 5. Print the final list — Expected: `['SP', 'RJ', 'MG', 'RS']`
# 6. How many states are now in the list? Expected: `4`

# %%
# Starting list — do not change this line
top_states = ["SP", "RJ", "MG"]

# Q2.1 — add "RS" to the end
# Your code here

# Q2.2 — insert "BA" at position 0
# Your code here

# Q2.3 — print the list
# Your code here

# Q2.4 — remove "BA"
# Your code here

# Q2.5 — print the final list
# Your code here

# Q2.6 — how many states?
# Your code here

# %% [markdown]
# ## Question 3 — List Aggregations
#
# Using `counts` (the order counts for each of the 8 statuses) and `review_scores`:
#
# 1. What is the total number of orders across all statuses? Expected: `99,441`
# 2. What is the maximum order count for any single status? Expected: `96,478`
# 3. What is the minimum order count? Expected: `2`
# 4. What is the average review score? Expected: `3.5`
# 5. How many times does the score `5` appear in `review_scores`? Expected: `4`

# %%
# Q3.1 — total orders
# Your code here

# Q3.2 — maximum count
# Your code here

# Q3.3 — minimum count
# Your code here

# Q3.4 — average review score
# Your code here

# Q3.5 — count of score 5
# Your code here

# %% [markdown]
# ## Question 4 — For Loop with `zip()`
#
# Using `statuses` and `counts`:
#
# 1. Calculate `total_orders = sum(counts)` (you'll need this for the percentage)
# 2. Write a `for` loop using `zip()` to print **the first 4 statuses only** in this format:
#    ```
#    delivered: 96,478 orders (97.0%)
#    shipped: 1,107 orders (1.1%)
#    canceled: 625 orders (0.6%)
#    unavailable: 609 orders (0.6%)
#    ```
#    *Hint*: use `statuses[:4]` and `counts[:4]` inside `zip()`, and format the percentage with `:.1f`.

# %%
# Q4.1 — total orders
total_orders = sum(counts)

# Q4.2 — for loop printing the first 4 statuses + percentages
# Your code here

# %% [markdown]
# ## Question 5 — `range()` and `enumerate()`
#
# 1. Use `range()` to print the even numbers from 2 to 10 (inclusive):
#    ```
#    2
#    4
#    6
#    8
#    10
#    ```
# 2. Use `enumerate()` on `statuses` to print the **first 5 statuses** numbered from 1:
#    ```
#    1. delivered
#    2. shipped
#    3. canceled
#    4. unavailable
#    5. invoiced
#    ```
#    *Hint*: use `statuses[:5]` inside `enumerate()` and add 1 to the index.

# %%
# Q5.1 — even numbers 2 to 10 using range()
# Your code here

# Q5.2 — first 5 statuses numbered from 1 using enumerate()
# Your code here

# %% [markdown]
# ## Question 6 — List Comprehensions: Filtering
#
# Using `review_scores = [5, 4, 1, 5, 3, 2, 5, 4, 5, 1]` and a **list comprehension** for each:
#
# 1. Create a list of scores that are **4 or above**. Expected: `[5, 4, 5, 5, 4, 5]`
# 2. Create a list of scores that are **exactly 5**. Expected: `[5, 5, 5, 5]`
# 3. Create a list of scores that are **below 3** (i.e. 1 or 2). Expected: `[1, 2, 1]`
# 4. How many scores are below 3? Expected: `3`

# %%
# Q6.1 — scores >= 4
# Your code here

# Q6.2 — scores == 5
# Your code here

# Q6.3 — scores < 3
# Your code here

# Q6.4 — count of scores below 3 (use your result from Q6.3)
# Your code here

# %% [markdown]
# ## Question 7 — List Comprehensions: Transforming
#
# Using `payment_types = ["credit_card", "boleto", "voucher", "debit_card", "not_defined"]`:
#
# 1. Create a list with all names in **UPPER CASE**. Expected: `['CREDIT_CARD', 'BOLETO', 'VOUCHER', 'DEBIT_CARD', 'NOT_DEFINED']`
# 2. Create a list where underscores are replaced with spaces (use `.replace("_", " ")`). Expected: `['credit card', 'boleto', 'voucher', 'debit card', 'not defined']`
# 3. Using **both** `payment_types` and `payment_counts` with `zip()` inside a comprehension, create a list of formatted strings:
#    Expected: `['credit_card: 76795', 'boleto: 19784', 'voucher: 5775', 'debit_card: 1529', 'not_defined: 3']`

# %%
# Q7.1 — UPPER CASE names
# Your code here

# Q7.2 — replace underscores with spaces
# Your code here

# Q7.3 — formatted strings combining type + count
# Your code here

# %% [markdown]
# ## Question 8 — Group Exercise: Olist Payment Analysis
#
# Olist recorded **103,886 payment transactions** split across 5 payment methods. Use the `payment_types` and `payment_counts` lists (already loaded above) to complete all five tasks.
#
# 1. Print the total number of payments. Expected: `103,886`
# 2. Using a `for` loop with `zip()`, print each payment type and its percentage of the total. Expected format: `credit_card: 76,795 transactions (73.9%)`
# 3. Using a list comprehension, create a list of **only** payment types where count > 1,000. Expected: `['credit_card', 'boleto', 'voucher', 'debit_card']`
# 4. Using a list comprehension, convert all payment type names to UPPER CASE.
# 5. Calculate the average transaction count per payment type. Expected: `20,777.2`

# %%
# Q8.1 — total payments
# Your code here

# Q8.2 — for loop: type + percentage
# Your code here

# Q8.3 — comprehension: types with count > 1,000
# Your code here

# Q8.4 — comprehension: names in UPPER CASE
# Your code here

# Q8.5 — average count per type
# Your code here
