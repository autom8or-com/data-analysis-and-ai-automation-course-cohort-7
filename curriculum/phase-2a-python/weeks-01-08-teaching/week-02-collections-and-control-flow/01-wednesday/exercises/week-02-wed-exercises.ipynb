# %% [markdown]
# **Exercise 1 — List Basics**
#
# Use the `statuses` list below to:
# - Print its length
# - Print the first element
# - Print the last element
# - Print the first three elements as a list
#
# Expected output:
# ```
# 8
# delivered
# approved
# ['delivered', 'shipped', 'canceled']
# ```

# %%
# Exercise 1: your code here
statuses = ["delivered", "shipped", "canceled", "unavailable", 
            "invoiced", "processing", "created", "approved"]

# Write four print statements (len, first, last, first three)

# %% [markdown]
# **Exercise 2 — List Statistics**
#
# Using the `counts` list (all 8 numbers), print:
# - Sum
# - Maximum
# - Minimum
# - Average (rounded to 2 decimal places)
#
# Expected output:
# ```
# Sum: 99441
# Max: 96478
# Min: 2
# Average: 12430.12
# ```

# %%
# Exercise 2: your code here
counts = [96478, 1107, 625, 609, 314, 301, 5, 2]

# Calculate and print sum, max, min, and average

# %% [markdown]
# **Exercise 3 — For Loop with `zip()`**
#
# Loop through the first five statuses and their counts (delivered, shipped, canceled, unavailable, invoiced) using `zip()`. Print each line in the format below (with comma separators for thousands).
#
# Expected output:
# ```
# delivered: 96,478 orders
# shipped: 1,107 orders
# canceled: 625 orders
# unavailable: 609 orders
# invoiced: 314 orders
# ```

# %%
# Exercise 3: your code here
statuses = ["delivered", "shipped", "canceled", "unavailable", "invoiced"]
counts = [96478, 1107, 625, 609, 314]

# Use zip and an f-string with :, formatting

# %% [markdown]
# **Exercise 4 — `range()` Loop**
#
# Use a `for` loop with `range()` to print "Order priority: 1", "Order priority: 2", ..., up to 5. Each on its own line.
#
# Expected output:
# ```
# Order priority: 1
# Order priority: 2
# Order priority: 3
# Order priority: 4
# Order priority: 5
# ```

# %%
# Exercise 4: your code here
# Loop using range(1, 6)
 and print each line

# %% [markdown]
# **Exercise 5 — List Comprehension (Filter)**
#
# From the `scores` list, create a new list `fives` containing only the scores that are exactly 5. Print the resulting list.
#
# Expected output:
# ```
# [5, 5, 5, 5]
# ```

# %%
# Exercise 5: your code here
scores = [5, 4, 1, 5, 3, 2, 5, 4, 5, 1]

# Use a list comprehension: [score for score in scores if score == 5]

# %% [markdown]
# **Exercise 6 — List Comprehension (Transform)**
#
# Convert the city names in `cities` to proper title case (first letter of each word capitalised) using a list comprehension and the `.title()` method. Store the result in `title_cities` and print it.
#
# Expected output:
# ```
# ['Sao Paulo', 'Rio De Janeiro', 'Belo Horizonte']
# ```

# %%
# Exercise 6: your code here
cities = ["sao paulo", "rio de janeiro", "belo horizonte"]

# Use a list comprehension: [city.title()
 for city in cities]

# %% [markdown]
# **Exercise 7 — Tuple Unpacking**
#
# Unpack the tuple `order` into variables `order_id, status, price, freight, state, review_score`. Then print a sentence using `state` and `review_score`.
#
# Expected output:
# ```
# Order from SP has review score 4
# ```

# %%
# Exercise 7: your code here
order = ('e481f51cbdc54678b7cc49136f2d6af7', 'delivered', 58.9, 13.29, 'SP', 4)

# Unpack and print the sentence

# %% [markdown]
# **Exercise 8 — List Modification**
#
# Start with `top_states = ['SP', 'RJ', 'MG']`. Extend the list by adding `'RS'` and `'PR'`. Then sort the list alphabetically and print the final list.
#
# Expected output:
# ```
# ['MG', 'PR', 'RJ', 'RS', 'SP']
# ```

# %%
# Exercise 8: your code here
top_states = ['SP', 'RJ', 'MG']

# Use .extend()
 and .sort()

# %% [markdown]
# **Exercise 9 — List Comprehension with Conditionals**
#
# Transform the `scores` list into a list of strings called `ratings` using a single list comprehension:
# - `'High'` if the score is 4 or above
# - `'Medium'` if the score is exactly 3
# - `'Low'` if the score is below 3
#
# Print `ratings`.
#
# Expected output:
# ```
# ['High', 'High', 'Low', 'High', 'Medium', 'Low', 'High', 'High', 'High', 'Low']
# ```

# %%
# Exercise 9: your code here
scores = [5, 4, 1, 5, 3, 2, 5, 4, 5, 1]

# Use nested ternary: 'High' if score>=4 else 'Medium' if score==3 else 'Low'

# %% [markdown]
# **Exercise 10 — `enumerate()` with Letters**
#
# Use `enumerate()` to loop through the `cities` list. Print each city preceded by a letter index (A, B, C, ...) and with proper capitalisation. Convert the index to a letter with `chr(65 + i)`.
#
# Expected output:
# ```
# A. Sao Paulo
# B. Rio De Janeiro
# C. Belo Horizonte
# ```

# %%
# Exercise 10: your code here
cities = ["sao paulo", "rio de janeiro", "belo horizonte"]

# Loop with enumerate and use chr(65+i)

# %% [markdown]
# **Exercise 11 — Processing a List of Tuples**
#
# `state_counts` is a list of `(state, order_count)` tuples representing the top 5 states.
# 1. Calculate the total number of orders.
# 2. Using a `for` loop, print each state and its percentage of total orders (1 decimal place).
#
# Expected output (approximate):
# ```
# SP: 54.4%
# RJ: 16.7%
# MG: 15.2%
# RS: 7.1%
# PR: 6.6%
# ```

# %%
# Exercise 11: your code here
state_counts = [('SP', 41746), ('RJ', 12852), ('MG', 11635), ('RS', 5466), ('PR', 5045)]

# First sum all counts, then loop and print with percentage

# %% [markdown]
# **Exercise 12 — Challenge: Combined Operations**
#
# Using the full `statuses` and `counts` lists (8 items each):
# 1. Create a list of tuples `status_info` where each tuple is `(status, count, len(status))`.
# 2. Use a list comprehension to filter only tuples with `count > 100`.
# 3. Sort the filtered list by the status length in **descending** order.
# 4. Loop through the sorted list and print each line as:
#    `Status: <status>, Count: <count>, Length: <length>`
#
# Expected output:
# ```
# Status: unavailable, Count: 609, Length: 11
# Status: processing, Count: 301, Length: 10
# Status: delivered, Count: 96478, Length: 9
# Status: canceled, Count: 625, Length: 8
# Status: invoiced, Count: 314, Length: 8
# Status: shipped, Count: 1107, Length: 7
# ```

# %%
# Exercise 12: your code here
statuses = ["delivered", "shipped", "canceled", "unavailable", 
            "invoiced", "processing", "created", "approved"]
counts = [96478, 1107, 625, 609, 314, 301, 5, 2]

# Create status_info using zip and len
# Filter with list comprehension (count > 100)
# Sort with key=lambda x: x[2], reverse=True
# Loop and print in required format
