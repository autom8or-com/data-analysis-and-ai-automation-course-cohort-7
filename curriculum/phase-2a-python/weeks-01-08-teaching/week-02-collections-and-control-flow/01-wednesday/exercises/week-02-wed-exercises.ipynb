# %% [markdown]
# # Week 2 — Collections & Control Flow
# ## Phase 2a Python | PORA Academy Cohort 7
#
# > *"The only way to learn a new programming language is by writing programs in it." — Dennis Ritchie*
#
# Welcome to **Week 2, Wednesday: Lists, Tuples & Loops**. Today, we apply our new Python skills to real data from the Olist Brazilian e‑commerce marketplace. Every exercise uses verified numbers — the same kind you’d see in a data analysis job. Let’s get started!

# %% [markdown]
# ## Group Exercise: Payment Methods in E‑Commerce
#
# Understanding **how customers pay** is crucial for any online store. In Nigeria, popular options include bank transfers, USSD, cards, and cash on delivery. The Olist dataset shows Brazil’s distribution — a mix of card payments, bank slips (‘boleto’), and vouchers.
#
# Here are the **verified transaction counts** by payment type:
#
# | Payment Type  | Count  |
# |---------------|--------|
# | credit_card   | 76,795 |
# | boleto        | 19,784 |
# | voucher       | 5,775  |
# | debit_card    | 1,529  |
# | not_defined   | 3      |
#
# ***Boleto*** is an official bank payment slip — similar to ‘pay on delivery’ or ‘bank deposit’. The tiny `not_defined` category contains transactions where the payment method wasn’t recorded.
#
# **Learning Objectives**
# - Create and manipulate lists
# - Use `for` loops and `range()`
# - Apply list comprehensions for simple transformations
# - Understand tuples and when to use them
#
# Over the next five tasks, you’ll practice `sum()`, `zip()`, `for` loops, and list comprehensions — the building blocks of data analysis in Python.

# %% [markdown]
# ### Q1: Total Payments
#
# Compute the total number of orders using the `sum()` function on `payment_counts`. This number becomes the denominator for all percentages later.
#
# `sum(payment_counts)` → **Expected: 103,886**
#
# *Hint:* Store the result in a variable called `total` — you’ll reuse it in the next exercise.

# %%
# Data from the exercise (already defined in your environment):
# payment_types = ['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined']
# payment_counts = [76795, 19784, 5775, 1529, 3]

# Your solution for Q1:

# %% [markdown]
# ### Q2: Percentage Breakdown
#
# Use a `for` loop with `zip(payment_types, payment_counts)` to print each payment method and its **percentage of total orders** (to one decimal place).
#
# Expected output:
# ```
# credit_card: 73.9%
# boleto: 19.0%
# voucher: 5.6%
# debit_card: 1.5%
# not_defined: 0.0%
# ```
#
# **Business insight:** In Brazil, 73.9% of online transactions use credit cards. If you ran a Nigerian e‑commerce site, which payment methods would you prioritise? Would you still offer boleto‑like options?
#
# Remember the formula:
# ```python
# percentage = (count / total) * 100
# ```

# %%
# Data reminder:
# payment_types and payment_counts are available from previous cells.
# Make sure you have 'total' defined (from Q1).

# Your for loop here:

# %% [markdown]
# ### Q3: Filter Major Payment Methods
#
# Create a **new list** containing only the payment types that have **more than 1,000 transactions**. Use a **list comprehension** with an `if` condition.
#
# Expected result:
# ```python
# ['credit_card', 'boleto', 'voucher', 'debit_card']
# ```
#
# List comprehensions are a concise way to build a list from another sequence:
# ```python
# [expression for item in iterable if condition]
# ```
# You’ll need to `zip` the types and counts, then filter by `cnt > 1000`. The tiny `not_defined` category (only 3 orders) gets dropped.

# %%
# Your list comprehension for Q3:

# %% [markdown]
# ### Q4: Uppercase Names
#
# Transform all payment type names to **UPPERCASE** using another list comprehension. For example,
# `'credit_card'` → `'CREDIT_CARD'`.
#
# Expected output:
# ```python
# ['CREDIT_CARD', 'BOLETO', 'VOUCHER', 'DEBIT_CARD', 'NOT_DEFINED']
# ```
#
# This is a common data cleaning step — standardising text for merging datasets or categorical analysis. The pattern is:
# ```python
# [p.upper() for p in payment_types]
# ```

# %%
# Your uppercase transformation here:

# %% [markdown]
# ### Q5: Average Transactions per Type
#
# Calculate the **average** number of transactions per payment method.
#
# Formula: `sum(payment_counts) / len(payment_counts)`
#
# Expected: `20,777.2`
#
# **Think about it:** The average is pulled way up by `credit_card` (76,795). Without it, the average would drop dramatically. That’s why data analysts often prefer the **median** for skewed data. For now, just compute the mean.
#
# Well done! You’ve now used lists, loops, `zip()`, and list comprehensions on real business data. In the next lesson, you’ll apply similar techniques with dictionaries and conditionals.

# %%
# Your average calculation here:
