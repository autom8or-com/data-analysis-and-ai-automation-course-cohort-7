# %% [markdown]
# # Week 3 — Functions & First Contact with Data: Functions Deep Dive
# ## Phase 2a Python | PORA Academy Cohort 7
# ### 🧩 Wednesday Exercises
#
# **Read each question carefully before you start typing.**
#
# These exercises practise everything from today's session: writing functions with
# parameters, default values, docstrings, and return values; returning multiple values
# as tuples; and guarding against errors with `try`/`except`.
#
# **How to work through this notebook:**
# - Each question has a code cell with a `# Your code here` placeholder. Replace it with your solution.
# - Some cells give you variables that are **already defined** — do not change those values.
# - An **expected output** is shown for every question. Run your cell and compare.
# - Work in your group for the final section (Build the Olist Toolkit).
#
# All numbers come from the real **Olist** Brazilian e-commerce dataset (99,441 orders).

# %% [markdown]
# ## Setup
#
# Week 3 is about writing **functions** — we are not loading any CSV files yet
# (that's Thursday). Run the cell below to pin down a few real Olist values you'll
# use throughout these exercises. **Do not change these values.**

# %%
# Real Olist values — no data loading needed for Wednesday's exercises
# Do not change these.

total_orders     = 99441      # total orders in the dataset
delivered_orders = 96478      # orders with status "delivered"
canceled_orders  = 625        # orders with status "canceled"

# Orders per state (top 5)
state_orders = {
    "SP": 41746,
    "RJ": 12852,
    "MG": 11635,
    "RS": 5466,
    "PR": 5045,
}

print("Setup complete — values are ready to use.")
# expected: Setup complete — values are ready to use.

# %% [markdown]
# ## Question 1 — Your first function: total order cost
#
# In Olist, every order line has an **item price** and a **freight (shipping) cost**.
# The total the customer pays is `price + freight`.
#
# Write a function `calculate_total_cost(price, freight)` that:
# - takes two arguments,
# - has a one-line **docstring**,
# - **returns** the total (does not just print it).
#
# Then call it on the three orders below.
#
# **Expected output:**
# ```
# 72.19
# 259.83
# 216.87
# ```

# %%
def calculate_total_cost(price, freight):
    # Your code here
    pass

# Test calls — do not change these values
print(calculate_total_cost(58.90, 13.29))    # expected: 72.19
print(calculate_total_cost(239.90, 19.93))   # expected: 259.83
print(calculate_total_cost(199.00, 17.87))   # expected: 216.87

# %% [markdown]
# ## Question 2 — Default parameters: classify a review score
#
# Olist customers leave a review score from **1 to 5**. Write a function
# `classify_review(score, positive_threshold=4, negative_threshold=2)` that returns:
# - `"Positive"` when the score is **at least** `positive_threshold`,
# - `"Negative"` when the score is **at most** `negative_threshold`,
# - `"Neutral"` otherwise.
#
# Notice the two **default parameters** — a caller can use them as-is or override them.
#
# **Expected output:**
# ```
# Score 1 → Negative
# Score 2 → Negative
# Score 3 → Neutral
# Score 4 → Positive
# Score 5 → Positive
# ```

# %%
def classify_review(score, positive_threshold=4, negative_threshold=2):
    """Classify a review score as Positive, Neutral, or Negative."""
    # Your code here
    pass

for s in [1, 2, 3, 4, 5]:
    print(f"Score {s} → {classify_review(s)}")
# expected:
# Score 1 → Negative
# Score 2 → Negative
# Score 3 → Neutral
# Score 4 → Positive
# Score 5 → Positive

# %% [markdown]
# ## Question 3 — Returning multiple values: delivery analysis
#
# A function can hand back **more than one value** at once by returning a tuple, and
# the caller can **unpack** it in a single line: `days, status = delivery_analysis(...)`.
#
# Write `delivery_analysis(purchase_date_str, delivery_date_str)` that:
# - parses both dates (format `"%Y-%m-%d %H:%M:%S"`),
# - computes the number of **days** between them,
# - classifies the delivery as `"Fast"` (≤ 7 days), `"Normal"` (≤ 14 days), or `"Slow"`,
# - **returns** `(days, status)` as a tuple.
#
# Wrap the date parsing in a `try`/`except` so a bad date returns `(None, "Unknown")`
# instead of crashing.
#
# **Expected output:**
# ```
# Days: 8, Status: Normal
# Days: 13, Status: Normal
# ```

# %%
from datetime import datetime

def delivery_analysis(purchase_date_str, delivery_date_str):
    """Return (days, classification) for an order's delivery time."""
    fmt = "%Y-%m-%d %H:%M:%S"
    # Your code here
    pass

# Test calls — do not change these values
days, status = delivery_analysis("2017-10-02 10:56:33", "2017-10-10 21:25:13")
print(f"Days: {days}, Status: {status}")   # expected: Days: 8, Status: Normal

days, status = delivery_analysis("2018-07-24 20:41:37", "2018-08-07 15:27:45")
print(f"Days: {days}, Status: {status}")   # expected: Days: 13, Status: Normal

# %% [markdown]
# ## Question 4 — Make `try`/`except` earn its keep
#
# Reuse your `delivery_analysis` function from Question 3. This time, call it with a
# **broken** delivery date (an empty string). Because you wrapped the parsing in a
# `try`/`except`, the function should hand back `(None, "Unknown")` rather than raising
# an error.
#
# **Expected output:**
# ```
# Days: None, Status: Unknown
# ```
#
# If your function crashes here, revisit Question 3 and make sure the `try`/`except`
# wraps the date parsing.

# %%
# Call delivery_analysis with a bad (empty) delivery date.
# Your code here


# expected: Days: None, Status: Unknown

# %% [markdown]
# ## 👥 Group Exercise — Build the Olist Toolkit
#
# Work together. You'll write **four small functions** that you could genuinely reuse
# across the rest of this course. Each function reinforces a skill from today:
# parameters, defaults, return values, and error handling.
#
# Test each function with the values given — the expected results are real Olist numbers.

# %% [markdown]
# ### Toolkit Function 1 — `summarise_orders(status_list, count_list)`
#
# Take **two lists** (one of status names, one of counts) and combine them into a
# **dictionary** `{status: count}`.
#
# > 💡 Hint: `zip()` pairs two lists together; `dict()` turns the pairs into a dict.
#
# **Expected output:**
# ```
# {'delivered': 96478, 'shipped': 1107, 'canceled': 625}
# ```

# %%
def summarise_orders(status_list, count_list):
    """Combine a list of statuses and a list of counts into a dict."""
    # Your code here
    pass

# Test — do not change these values
statuses = ["delivered", "shipped", "canceled"]
counts   = [96478, 1107, 625]
print(summarise_orders(statuses, counts))
# expected: {'delivered': 96478, 'shipped': 1107, 'canceled': 625}

# %% [markdown]
# ### Toolkit Function 2 — `top_n_items(data_dict, n=5)`
#
# Take a dictionary of `{key: numeric_value}` and return the **top `n`** items as a
# list of `(key, value)` tuples, sorted from highest value to lowest. Give `n` a
# **default** of `5`.
#
# > 💡 Hint: `sorted(data_dict.items(), key=..., reverse=True)` then slice `[:n]`.
#
# **Test:** `top_n_items(state_orders, 3)`
#
# **Expected output:**
# ```
# [('SP', 41746), ('RJ', 12852), ('MG', 11635)]
# ```

# %%
def top_n_items(data_dict, n=5):
    """Return the top n (key, value) pairs sorted by value, descending."""
    # Your code here
    pass

# Test — uses state_orders defined in the Setup cell
print(top_n_items(state_orders, 3))
# expected: [('SP', 41746), ('RJ', 12852), ('MG', 11635)]

# %% [markdown]
# ### Toolkit Function 3 — `format_currency(amount, currency="R$")`
#
# Olist prices are in Brazilian reais. Write a function that turns a number into a
# clean currency string with **thousands separators** and **two decimal places**.
# Give `currency` a **default** of `"R$"`.
#
# > 💡 Hint: an f-string format spec does the heavy lifting: `f"{amount:,.2f}"`.
#
# **Test:** `format_currency(5202955.05)`
#
# **Expected output:**
# ```
# R$5,202,955.05
# ```

# %%
def format_currency(amount, currency="R$"):
    """Format a number as a currency string, e.g. R$5,202,955.05."""
    # Your code here
    pass

# Test — total Olist revenue
print(format_currency(5202955.05))
# expected: R$5,202,955.05

# %% [markdown]
# ### Toolkit Function 4 — `safe_divide(numerator, denominator, default=0.0)`
#
# Division by zero crashes a program. Write a function that returns
# `numerator / denominator`, but returns `default` (default value `0.0`) whenever the
# denominator is `0`.
#
# > 💡 Hint: this is a perfect job for `try`/`except ZeroDivisionError`, or a simple
# > `if denominator == 0` check.
#
# **Tests:**
# - `safe_divide(96478, 99441)` → the delivered-order **rate** (`0.9702...`)
# - `safe_divide(100, 0)` → `0.0` (no crash!)
#
# **Expected output:**
# ```
# 0.9702...
# 0.0
# ```

# %%
def safe_divide(numerator, denominator, default=0.0):
    """Divide safely; return `default` if denominator is 0."""
    # Your code here
    pass

# Tests — do not change these values
print(safe_divide(96478, 99441))   # expected: 0.9702... (delivered rate)
print(safe_divide(100, 0))         # expected: 0.0

# %% [markdown]
# ## ✅ Before you move on
#
# Check that you can answer **yes** to each of these:
#
# | Skill | Did you use it? |
# |---|---|
# | Define a function with parameters and a `return` | Q1 |
# | Use **default parameter** values | Q2, Toolkit 2/3/4 |
# | Return **multiple values** as a tuple and unpack them | Q3 |
# | Guard against errors with `try`/`except` | Q3, Q4, Toolkit 4 |
# | Write a **docstring** | Every function |
#
# ---
# **Coming up Thursday — _Reading Real Data with Python_:** you'll open the actual
# `olist_orders_dataset.csv` file with Python's `csv` module, load all 99,441 rows into
# a list of dicts, and apply the very functions you just wrote to real data.
